# %%
import numpy as np
from lattice import lattice_2D
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.preprocessing import normalize
from LLGS_simulation import LLGS_Simulation_2D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
import glob
from numba import njit, prange

# %%
problem_name = "NiPS3_rotation"
Hexagonal_monolayer = lattice_2D(2,4,4)
Hexagonal_monolayer.set_position(
    r_a = np.array([1,0]),
    r_b = np.array([0.5,0.5*np.sqrt(3)]),
    r_site = np.array((
    [0.5,np.sqrt(3)/6] #first site
    ,[1,np.sqrt(3)/3] #second site
    ))
)

# %%
def initial_AFM_ZigZagChain(lattice:lattice_2D):
    """
        Initial particles
    """
    N=lattice.N
    sx=np.zeros(N)
    sy=np.zeros(N)
    for n in range(N):
        if lattice._tag[n,2]%2==0:
            sx[n]=1
        else:
            sx[n]=-1
    sy=np.random.normal(0,0.1,N)
    sz=np.zeros(N)
    spins = np.transpose(np.vstack((sx,sy,sz)))
    spins_normalized = normalize(spins)

    lattice.set_spins(spins_normalized)
    return lattice

# %%
initial_AFM_ZigZagChain(Hexagonal_monolayer)

# %%
tags = Hexagonal_monolayer._tag.astype(np.int32)

def H_E_NiPS3_fully_conected(tags,J_1=0,J_2=0,J_3=0):
    N = len(tags[:,0])
    H_E = np.zeros((N,N))

    site = tags[:,0]
    a = tags[:,1]
    b = tags[:,2]

    def is_neighbor(i,j):
        if site[i] != site[j]:
            if a[j] == a[i] and b[j] == b[i]:
                return True
            elif a[j] == a[i]+site[i]-site[j] and b[j] == b[i]:
                return True
            elif a[j] == a[i] and b[j] == b[i]+site[i]-site[j]:
                return True
            else:
                return False        
        else:
            return False
    
    def is_next_nearest_neighbor(i,j):
        if site[i] == site[j]:
            if a[j] == a[i]+1 and b[j] == b[i]:
                return True
            elif a[j] == a[i]-1 and b[j] == b[i]:
                return True
            elif a[j] == a[i] and b[j] == b[i]+1:
                return True
            elif a[j] == a[i] and b[j] == b[i]-1:
                return True
            elif a[j] == a[i]-1 and b[j] == b[i]+1:
                return True
            elif a[j] == a[i]+1 and b[j] == b[i]-1:
                return True
            else:
                return False        
        else:
            return False

    def is_next_next_nearest_neighbor(i,j):
        if site[i] != site[j]:
            if a[j] == a[i]-1 and b[j] == b[i]+1:
                return True
            elif a[j] == a[i]+1 and b[j] == b[i]-1:
                return True
            elif a[j] == a[i]+site[i]-site[j] and b[j] == b[i]+site[i]-site[j]:
                return True
            else:
                return False        
        else:
            return False

    def update_H_E():
        for i in range(N):
            for j in range(N):
                if is_neighbor(i,j) == True:
                    H_E[i,j] = J_1
                elif is_next_nearest_neighbor(i,j) == True:
                    H_E[i,j] = J_2
                elif is_next_next_nearest_neighbor(i,j) == True:
                    H_E[i,j] = J_3
        return

    a_max = np.max(a)
    b_max = np.max(b)
    update_H_E()                    #initial update
    a = np.where(a==a_max,-1,a)
    update_H_E()                    #consider a_max = a_-1
    a = np.where(a==-1,a_max,a)
    b = np.where(b==b_max,-1,b)
    update_H_E()                    #consider b_max = b_-1
    a = np.where(a==a_max,-1,a)     #consider a_max = a_-1 and b_max = b_-1
    update_H_E()


    return H_E

H_E = H_E_NiPS3_fully_conected(tags,J_1=-32.76,J_2=1.72,J_3=118.96)
print(H_E)
# Out:
dt= 1e-06
# fn = data_NiPS3_rotation/RK4_06300.txt time = 0.006300000000000512 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_06400.txt time = 0.006400000000000525 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_06500.txt time = 0.006500000000000538 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_06600.txt time = 0.006600000000000552 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_06700.txt time = 0.006700000000000565 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_06800.txt time = 0.006800000000000578 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_06900.txt time = 0.006900000000000591 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_07000.txt time = 0.007000000000000605 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_07100.txt time = 0.007100000000000618 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_07200.txt time = 0.007200000000000631 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_07300.txt time = 0.0073000000000006445 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_07400.txt time = 0.007400000000000658 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_07500.txt time = 0.007500000000000671 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_07600.txt time = 0.007600000000000684 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_07700.txt time = 0.007700000000000698 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_07800.txt time = 0.007800000000000711 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_07900.txt time = 0.007900000000000648 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_08000.txt time = 0.008000000000000574 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_08100.txt time = 0.008100000000000501 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_08200.txt time = 0.008200000000000427 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_08300.txt time = 0.008300000000000354 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_08400.txt time = 0.00840000000000028 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_08500.txt time = 0.008500000000000207 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_08600.txt time = 0.008600000000000134 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_08700.txt time = 0.00870000000000006 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_08800.txt time = 0.008799999999999987 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_08900.txt time = 0.008899999999999913 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_09000.txt time = 0.00899999999999984 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_09100.txt time = 0.009099999999999766 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_09200.txt time = 0.009199999999999693 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_09300.txt time = 0.00929999999999962 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_09400.txt time = 0.009399999999999546 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_09500.txt time = 0.009499999999999472 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_09600.txt time = 0.009599999999999399 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_09700.txt time = 0.009699999999999325 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_09800.txt time = 0.009799999999999252 dt= 1e-06
# fn = data_NiPS3_rotation/RK4_09900.txt time = 0.009899999999999179 dt= 1e-06
# simulation is done

# %%
fns = "data_"+problem_name+"/"+method+"_[0-9][0-9][0-9][0-9][0-9].txt"
fns = glob.glob(fns)
fns.sort()

H_ex=np.zeros(len(fns))
for i in range(len(fns)):
    sx,sy,sz = np.transpose(np.loadtxt(fns[i]))
    H_ex[i] = np.dot(sx,np.dot(H_E,sx)) + np.dot(sy,np.dot(H_E,sy)) +np.dot(sz,np.dot(H_E,sz))
plt.plot(np.linspace(0,tmax,len(fns)),H_ex)

# %%
plt.style.use("dark_background")
plt.set_cmap('bwr')

fig, ax =plt.subplots()
#fig.set_size_inches(20, 20, forward=True)
#fig.set_dpi(72)
line = ax.plot([],[])

cmap = plt.get_cmap("bwr")
norm = mpl.colors.Normalize(vmin=-1, vmax=1)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
plt.colorbar(sm,ax=ax)

def init():
    fn_structure = "data_"+problem_name+"/structure.txt"
    site,a,b,x,y = np.transpose(np.loadtxt(fn_structure))
    ax.plot(x,y,'w.',markersize=2)

    return line

def updateLattice(frame):
    fn_structure = "data_"+problem_name+"/structure.txt"
    fn = fns[frame]
    sx,sy,sz = np.transpose(np.loadtxt(fn))
    site,a,b,x,y = np.transpose(np.loadtxt(fn_structure))

    arrowscale=0.3
    ax.clear()
    ax.plot(x,y,'w.',markersize=2)
    ax.quiver(x,y,sx*arrowscale,sy*arrowscale,sz,norm=norm)
    ax.set_aspect('equal')
    ax.axis("off")
    plt.title(f"time = {(frame*dt):0.3f} ns")

    return line


fns = "data_"+problem_name+"/"+method+"_[0-9][0-9][0-9][0-9][0-9].txt"
fns = glob.glob(fns)
fns.sort()
ani = animation.FuncAnimation(fig, updateLattice, frames=len(fns),init_func=init, blit=True)
ani.save('movie_'+problem_name+'.mp4',fps=10)
